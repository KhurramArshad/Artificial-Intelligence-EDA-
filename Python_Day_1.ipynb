# %% [markdown]
# <a href="https://colab.research.google.com/github/KhurramArshad/Artificial-Intelligence-EDA-/blob/main/Python_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Python's Core Data Types**
#
# ![Screenshot from 2023-07-17 12-03-57.png](data:image/png;base64,...)

# %% [markdown]
# ###**Numbers**
#
#
#
# *   **integers** (numbers with-out a fractional part)
# *   **floating-point numbers** (roughly, numbers with a decimal point in them)
# * **complex numbers** (a + ib)
#
# Numbers in Python support the normal mathematical operations. For instance, the
# **plus sign** ( + ) performs addition, a **star** ( * ) is used for multiplication, and **two stars** ( ** ) are used for exponentiation

# %%
123 + 222  # Integer addition
# Out:
# 345

# %%
1.5 * 4    # Floating-point multiplication
# Out:
# 6.0

# %%
2 ** 100   # 2 to the power 100
# Out:
# 1267650600228229401496703205376

# %% [markdown]
# **Notice the last result** here: Python 3.0’s integer type automatically provides extra pre-cision for large numbers like this when needed
#
# You can, for instance, compute 2 to the power 1,000,000 as an integer in Python, but you probably shouldn’t try to print the result—with more than 300,000 digits

# %% [markdown]
# Besides expressions, there are a handful of useful **numeric modules** that ship with Python—modules are just packages of additional tools that we import to use:

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(100)
# Out:
# 10.0

# %% [markdown]
# The **math module** contains more advanced numeric tools as functions, while the random module performs **random number generation** and random selections

# %%
import random
random.random()
# Out:
# 0.29711574007435515

# %%
random.choice([1, 2, 3, 4])
# Out:
# 2

# %% [markdown]
# ###**Stings**
#
# Strings are used to record textual information.
#
# Strings are our first example of what we call a sequence in Python. that is, a **positionally ordered** collection.
#
#
# Sequences maintain a **left-to-right** (**rigth-to-left**) order among the items they contain: their items are stored and fetched by their relative position. Strictly
# speaking, strings are sequences of one-character strings; other types of sequences in-clude lists and tuples, covered later.
#
# **Representation of String**
#
# (with double quotes) "Hello World"
#
# (with single quotes) 'Hello World'
#
# (multi Line Srting)
#
#               """
#               Hello world!
#               i am learning python,
#               it is very easy language
#               """
#
# **Sequence Operations**
#
# As sequences, strings support operations that assume a positional ordering among items. For example, if we have a four-character string, we can verify its length with the built-in len function and fetch its components with indexing expressions:

# %%
S = 'Python'
len(S)   #finding length
# Out:
# 6

# %%
S[0]
# Out:
# 'P'

# %%
S[3]
# Out:
# 'h'

# %%
S[-1]
# Out:
# 'n'

# %%
S[-2]
# Out:
# 'o'

# %% [markdown]
# **Notice** how we assign the string to a variable named S here. We’ll go into detail on how this works later, but Python variables never need to be declared
# ahead of time. A variable is created when you assign it a value, may be assigned any type of object, and is replaced with its value when it shows up in an expression. It must also have been previously assigned by the time you use its value. For the purposes of now, it’s enough to know that we need to assign an object to a variable in order to save it for later use.
#
#
# Formally, a negative index is simply added to the string’s size, so the following two operations are equivalent (**though the first is easier to code and less easy to get wrong**):

# %%
S[5]
# Out:
# 'n'

# %%
S[len(S)-1]
# Out:
# 'n'

# %% [markdown]
# **Notice that** we can use an arbitrary expression in the square brackets, not just a hard-coded number literal—anywhere that Python expects a value, we can use a literal, a variable, or any expression. Python’s syntax is completely general this way.

# %% [markdown]
# **Slicing**
#
# In addition to simple positional indexing, sequences also support a more general form of indexing known as **slicing**, which is a way to extract an entire section (slice) in a single step. **For example**:

# %%
S
# Out:
# 'Python'

# %%
S[1:3]    # Slice of S from offsets 1 through 2 (not 3)
# Out:
# 'yt'

# %%
S[1:]
# Out:
# 'ython'

# %%
S      # observe S itself hasn't changed
# Out:
# 'Python'

# %%
S[0:3]  # Everything but the last
# Out:
# 'Pyt'

# %%
S[:3]    # Same as S[0:3]
# Out:
# 'Pyt'

# %%
S[:]
# Out:
# 'Python'

# %%
S = 'abcdefghijklmnop'

S[1:10:2]
# Out:
# 'bdfhj'

# %%
S[::2]
# Out:
# 'acegikmo'

# %%
S[slice(1,10,2)]
# Out:
# 'bdfhj'

# %% [markdown]
# **Note that** how the last operation effectively copies the entire string
#
# for example:
#
#
# **S1 = S** (keeping S inside S1 does not make a copy of S but pionting to same object) but with
#
# **S1 = S[:]** (this will make a new object in the memory as copy of S)

# %% [markdown]
# **Practice Question**: if S = 'spam' then slice the string and show the following output
#
#
#
# 1.   'pa'
# 2.   'pam'
# 3. 'spa'

# %%
S = 'spam'
S[1:3], S[1:], S[:-1]
# Out:
# ('pa', 'pam', 'spa')

# %% [markdown]
# Finally, as sequences, strings also support **concatenation** with the plus sign (joining two strings into a new string) and **repetition** (making a new string by repeating another):

# %%
S
# Out:
# 'Python'

# %%
S + 'WithKhurram'   # Concatenation
# Out:
# 'PythonWithKhurram'

# %%
S     # S is unchanged
# Out:
# 'Python'

# %%
S * 8    # Repetition
# Out:
# 'PythonPythonPythonPythonPythonPythonPythonPython'

# %%
print('------- ...more... ---')  # 80 dashes, the hard way
# Out:
# ------- ...more... ---

# %%
print('-' * 80)  # 80 dashes, the easy way
# Out:
# --------------------------------------------------------------------------------

# %% [markdown]
# **Practice Question:**
# if,
#
#
# S = 'spammy'
#
# need output:
#
# 'spaxxy'

# %%
S = 'spammy'

S = S[:3] + "xx" + S[len(S)-1]

S
# Out:
# 'spaxxy'

# %%
# OR
S = 'spammy'

S = S.replace("mm", "xx")

S
# Out:
# 'spaxxy'

# %% [markdown]
# **Notice that** the plus sign ( + ) means different for different objects: addition for numbers, and concatenation for strings. This is a general property of Python that we’ll call **polymorphism**
#
# in sum, the meaning of an operation depends on the objects being operated on. As you’ll see when we study dynamic typing, this poly-morphism property accounts for much of the conciseness and flexibility of Python code.

# %% [markdown]
# **Immutability**
#
# Notice that in the prior examples, we were not changing the original string with any of the operations we ran on it. Every string operation is defined to produce a new string as its result, because strings are immutable in Python—they cannot be changed in-place after they are created. For example, you can’t change a string by assigning to one of its positions, but you can always build a new one and assign it to the same name. Because Python cleans up old objects as you go (as you’ll see later), this isn’t as inefficient as it
# may sound:

# %%
S
# Out:
# 'Python'

# %%
S[0] = 'z'   # Immutable objects cannot be changed (received an error)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-4d394d629d53> in <cell line: 1>()
# ----> 1 S[0] = 'z'   # Immutable objects cannot be changed (received an error)
#
# TypeError: 'str' object does not support item assignment

# %%
S = 'K' + S[1:]

# %%
S
# Out:
# 'Kython'

# %% [markdown]
# Every object in Python is classified as either immutable (unchangeable) or not. In terms of the core types, numbers, strings, and tuples are immutable; lists and dictionaries are not (they can be changed in-place freely). Among other things, immutability can be used to guarantee that an object remains constant throughout your program.

# %% [markdown]
# **Sting Methods**

# %% [markdown]
# **str.find() Method**

# %%
S = "Pakistan"

# %%
S.find('t')  # Find the offset of a substring (returns index if found)
# Out:
# 5

# %%
S.find('G')  # (return -1 if not found)
# Out:
# -1

# %% [markdown]
# **str.replace() Method**

# %%
S.replace('Pa', 'Na') # Replace occurrences of a substring with another

# %%
S
# Out:
# 'Pakistan'

# %% [markdown]
# **str.split() Method**

# %%
line = 'aaa,bbb,ccccc,dd'

line.split(',')  # Split on a delimiter into a list of substrings
# Out:
# ['aaa', 'bbb', 'ccccc', 'dd']

# %% [markdown]
# **str.upper(), str.lower() Methods**

# %%
country = "Pakistan"

country.upper()
# Out:
# 'PAKISTAN'

# %%
country.lower()
# Out:
# 'pakistan'

# %% [markdown]
# **str.isalpha() Method**

# %%
M = "Python"  # Content tests: isalpha, isdigit, etc.

M.isalpha()
# Out:
# True

# %%
M = "Python123"

M.isalpha()
# Out:
# False

# %% [markdown]
# **str.rstrip() Method**

# %%
MyString = "Python is easy        \n" # Remove whitespace characters on the right side

MyString.rstrip()
# Out:
# 'Python is easy'

# %%
password = "     special@12" # Remove whitespace characters on the left side

password.lstrip()
# Out:
# 'special@12'

# %%
L = "    xyx    \n  "

L.strip()  # Return a copy of the string with leading and trailing whitespace removed.
# Out:
# 'xyx'

# %% [markdown]
# **str.join() Method**

# %%
'SPAM'.join(['eggs', 'sausage', 'ham', 'toast'])
# Out:
# 'eggsSPAMsausageSPAMhamSPAMtoast'

# %% [markdown]
# **Strings also support an advanced substitution operation known as formatting**

# %%
'%s, eggs, and %s' % ('My', 'Bread!')  # Formatting expression (all)
# Out:
# 'My, eggs, and Bread!'

# %%
'{}, eggs, and {}'.format('My', 'Bread!')
# Out:
# 'My, eggs, and Bread!'

# %%
'{0}, eggs, and {1}'.format('My', 'Bread!')
# Out:
# 'My, eggs, and Bread!'

# %%
'{1}, eggs, and {0}'.format('My', 'Bread!')
# Out:
# 'Bread!, eggs, and My'

# %%
'{friend1} and {friend2} are friends'.format(friend1 = 'Ali', friend2 = 'Aslam!')
# Out:
# 'Ali and Aslam! are friends'

# %%
'{friend2} and {friend1} are friends'.format(friend1 = 'Ali', friend2 = 'Aslam!')
# Out:
# 'Aslam! and Ali are friends'

# %% [markdown]
# **Practice Question:**
#
# if x = 1234
#
# required Output string As
#
# "Integer is 1234 and with two zeros on most left is 001234"

# %%
x = 1234

result = "Integer %d and with two zeros on most left is decimal %06d" %(x,x)

result
# Out:
# 'Integer 1234 and with two zeros on most left is decimal 001234'

# %% [markdown]
# Another Example

# %%
'%f, %.2f, %.*f' % (1/3.0, 1/3.0, 4, 1/3.0)
# Out:
# '0.333333, 0.33, 0.3333'

# %% [markdown]
# **Getting Help**

# %%
S = "Python"

dir(S)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
help(S.replace)
# Out:
# Help on built-in function replace:
#
# replace(old, new, count=-1, /) method of builtins.str instance
#     Return a copy with all occurrences of substring old replaced by new.
#
#       count
#         Maximum number of occurrences to replace.
#         -1 (the default value) means replace all occurrences.
#
#     If the optional argument count is given, only the first count occurrences are
#     replaced.

# %% [markdown]
# **Pattern Matching**

# %%
import re

match = re.match('/(.*)/(.*)/(.*)', '/usr/home/khurram')

match.groups()
# Out:
# ('usr', 'home', 'khurram')
